# %% [markdown]
# # Extracting GPE Entities in One Book

# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Charles Dickens\\entities\\GPE'

# %%
data = pd.read_csv(r"Files\a_christmas_carol.entities.csv", delimiter=';')
data
# Out:
#       COREF  start_token  end_token  prop  cat             text
# 0         0            1          1  PRON  PER                I
# 1         0           22         22  PRON  PER               my
# 2        -1           22         23   NOM  PER       my readers
# 3        -1           28         28  PRON  PER       themselves
# 4        -1           31         32   NOM  PER       each other
# ...     ...          ...        ...   ...  ...              ...
# 4771     23        37008      37008  PROP  PER              God
# 4772     -1        37010      37010  PRON  PER               Us
# 4773     86        37049      37050  PROP  PER  Charles Dickens
# 4774     26        37055      37055  PROP  PER          Scrooge
# 4775     86        37080      37081  PROP  PER  Charles Dickens
#
# [4776 rows x 6 columns]

# %% [markdown]
# Let's start having a look at how the category "Location" looks like

# %%
location = data[data["cat"] == "LOC"]

# %%
location
# Out:
#       COREF  start_token  end_token  prop  cat  \
# 33       -1          231        232   NOM  LOC
# 294      -1         2172       2173   NOM  LOC
# 688      -1         5155       5155   NOM  LOC
# 854      -1         6613       6614   NOM  LOC
# 863      -1         6684       6685   NOM  LOC
# 865      -1         6704       6704   NOM  LOC
# 942      -1         7277       7278   NOM  LOC
# 1082      7         8439       8441  PROP  LOC
# 1105     -1         8794       8795   NOM  LOC
# 1232     -1        10199      10199  PRON  LOC
# 1233      8        10233      10234  PROP  LOC
# 1267     -1        10465      10466   NOM  LOC
# 1276     -1        10513      10515   NOM  LOC
# 1400     -1        11381      11382   NOM  LOC
# 1411     -1        11427      11429   NOM  LOC
# 1490     -1        11954      11956   NOM  LOC
# 1805     -1        14485      14486   NOM  LOC
# 1808     -1        14526      14527   NOM  LOC
# 1938     -1        15439      15441   NOM  LOC
# 2015     -1        16085      16086   NOM  LOC
# 2019     -1        16108      16109   NOM  LOC
# 2208     -1        18293      18294   NOM  LOC
# 2277     -1        19054      19058   NOM  LOC
# 2300     -1        19209      19210   NOM  LOC
# 2752     -1        22672      22676   NOM  LOC
# 2753     -1        22690      22690  PRON  LOC
# 2754     -1        22692      22697   NOM  LOC
# 2757     -1        22804      22808   NOM  LOC
# 2758     -1        22807      22808   NOM  LOC
# 2789     -1        23014      23015   NOM  LOC
# 2790     -1        23022      23022   NOM  LOC
# 2791     -1        23025      23025   NOM  LOC
# 2794     -1        23037      23041   NOM  LOC
# 2795     -1        23040      23041   NOM  LOC
# 2796     -1        23043      23047   NOM  LOC
# 2799     -1        23085      23086   NOM  LOC
# 2800     -1        23090      23095   NOM  LOC
# 2801     -1        23102      23110   NOM  LOC
# 2804     -1        23152      23153   NOM  LOC
# 2807     -1        23198      23200   NOM  LOC
# 2821     -1        23302      23303   NOM  LOC
# 2839     -1        23477      23479   NOM  LOC
# 2862     -1        23664      23665   NOM  LOC
# 3213     -1        26046      26047   NOM  LOC
# 3392     -1        27468      27471   NOM  LOC
# 3767     15        30397      30398  PROP  LOC
# 3789     -1        30760      30761   NOM  LOC
# 3959     -1        31890      31891   NOM  LOC
# 4223     -1        33342      33344   NOM  LOC
# 4282     16        33771      33772  PROP  LOC
# 4345     -1        34241      34242   NOM  LOC
# 4748     -1        36825      36828   NOM  LOC
# 4755     -1        36863      36864   NOM  LOC
#
#                                                text
# 33                                      the Country
# 294                                       the world
# 688                                             sea
# 854                                       the earth
# 863                                       the world
# 865                                           earth
# 942                                      this earth
# 1082                            the Invisible World
# 1105                                      the world
# 1232                                             it
# 1233                                    Good Heaven
# 1267                                  winding river
# 1276                               the broad fields
# 1400                                     the island
# 1411                               the little creek
# 1490                                  all the world
# 1805                                      the world
# 1808                                      the world
# 1938                                  all the world
# 2015                                      the world
# 2019                                     this place
# 2208                                      the woods
# 2277                       the many worlds about us
# 2300                                     this earth
# 2752                        a bleak and desert moor
# 2753                                             it
# 2754                   the burial - place of giants
# 2757                        the bowels of the earth
# 2758                                      the earth
# 2789                                       the moor
# 2790                                            sea
# 2791                                            sea
# 2794                           the last of the land
# 2795                                       the land
# 2796                     a frightful range of rocks
# 2799                                      the earth
# 2800                  a dismal reef of sunken rocks
# 2801  shore , on which the waters chafed and dashed
# 2804                                      the water
# 2807                                  the awful sea
# 2821                                      any shore
# 2839                               an unknown abyss
# 2862                                      the world
# 3213                                  foreign lands
# 3392                                the heart of it
# 3767                                Merciful Heaven
# 3789                                      the world
# 3959                                      the world
# 4223                                 a worthy place
# 4282                                       the Past
# 4345                                      the world
# 4748                             the good old world
# 4755                                     this globe

# %% [markdown]
# That looks a little bit abstract. Let's try GPE instead

# %%
gpe = data[data["cat"] == "GPE"]
gpe
# Out:
#       COREF  start_token  end_token  prop  cat  \
# 336       1         2424       2424  PROP  GPE
# 426      -1         2990       2990   NOM  GPE
# 537       3         3903       3904  PROP  GPE
# 574      -1         4165       4166   NOM  GPE
# 578      -1         4185       4187   NOM  GPE
# 579       4         4188       4188  PROP  GPE
# 683       5         5132       5132  PROP  GPE
# 773       4         5960       5960  PROP  GPE
# 900      -1         6939       6940   NOM  GPE
# 1108     -1         8833       8834   NOM  GPE
# 1201     -1         9912       9912   NOM  GPE
# 1231     -1        10189      10190   NOM  GPE
# 1239     -1        10256      10257   NOM  GPE
# 1263     -1        10447      10451   NOM  GPE
# 1372      9        11229      11229  PROP  GPE
# 1389     -1        11324      11325   NOM  GPE
# 1412     10        11431      11431  PROP  GPE
# 1555     -1        12409      12410   NOM  GPE
# 1558     -1        12436      12438   NOM  GPE
# 1609     26        12735      12735  PROP  GPE
# 1628     26        12882      12882  PROP  GPE
# 2052      4        16411      16411  PROP  GPE
# 2186     -1        17999      18000   NOM  GPE
# 2188     -1        18030      18031   NOM  GPE
# 2318     -1        19310      19311   NOM  GPE
# 3157      4        25596      25596  PROP  GPE
# 3295     -1        26719      26720   NOM  GPE
# 3312      4        26874      26874  PROP  GPE
# 3387     -1        27440      27441   NOM  GPE
# 3388     -1        27444      27445   NOM  GPE
# 3535     -1        28471      28494   NOM  GPE
# 3536     -1        28475      28476   NOM  GPE
# 3829     -1        31019      31020   NOM  GPE
# 4021     -1        32238      32239   NOM  GPE
# 4225     -1        33379      33381   NOM  GPE
# 4459      3        35221      35222  PROP  GPE
# 4744     -1        36806      36809   NOM  GPE
# 4745     -1        36813      36817   NOM  GPE
# 4746     -1        36819      36819   NOM  GPE
# 4747     -1        36822      36822   NOM  GPE
#
#                                                    text
# 336                                              Bedlam
# 426                                               there
# 537                                         Camden Town
# 574                                          that place
# 578                                         the City of
# 579                                              London
# 683                                               Sheba
# 773                                              London
# 900                                       other regions
# 1108                                      United States
# 1201                                              there
# 1231                                           The city
# 1239                                         this place
# 1263                             a little market - town
# 1372                                           Damascus
# 1389                                           the city
# 1412                                             Halloa
# 1555                                             a city
# 1558                                        a real city
# 1609                                           Ebenezer
# 1628                                           Ebenezer
# 2052                                             London
# 2186                                      Great Britain
# 2188                                           the town
# 2318                                           the town
# 3157                                             London
# 3295                                           the city
# 3312                                             London
# 3387                                           the city
# 3388                                           the city
# 3535  an obscure part of the town , where Scrooge ha...
# 3536                                           the town
# 3829                                           the town
# 4021                                            a place
# 4225                                     A worthy place
# 4459                                        Camden Town
# 4744                                  the good old city
# 4745                            any other good old city
# 4746                                               town
# 4747                                            borough

# %% [markdown]
# That looks much better! Let's stick with that. Now let's remove duplicates!

# %%
df = gpe.drop_duplicates(subset=['text'])

# %%
len(df)
# Out:
# 27

# %%
df
# Out:
#       COREF  start_token  end_token  prop  cat  \
# 336       1         2424       2424  PROP  GPE
# 426      -1         2990       2990   NOM  GPE
# 537       3         3903       3904  PROP  GPE
# 574      -1         4165       4166   NOM  GPE
# 578      -1         4185       4187   NOM  GPE
# 579       4         4188       4188  PROP  GPE
# 683       5         5132       5132  PROP  GPE
# 900      -1         6939       6940   NOM  GPE
# 1108     -1         8833       8834   NOM  GPE
# 1231     -1        10189      10190   NOM  GPE
# 1239     -1        10256      10257   NOM  GPE
# 1263     -1        10447      10451   NOM  GPE
# 1372      9        11229      11229  PROP  GPE
# 1389     -1        11324      11325   NOM  GPE
# 1412     10        11431      11431  PROP  GPE
# 1555     -1        12409      12410   NOM  GPE
# 1558     -1        12436      12438   NOM  GPE
# 1609     26        12735      12735  PROP  GPE
# 2186     -1        17999      18000   NOM  GPE
# 2188     -1        18030      18031   NOM  GPE
# 3535     -1        28471      28494   NOM  GPE
# 4021     -1        32238      32239   NOM  GPE
# 4225     -1        33379      33381   NOM  GPE
# 4744     -1        36806      36809   NOM  GPE
# 4745     -1        36813      36817   NOM  GPE
# 4746     -1        36819      36819   NOM  GPE
# 4747     -1        36822      36822   NOM  GPE
#
#                                                    text
# 336                                              Bedlam
# 426                                               there
# 537                                         Camden Town
# 574                                          that place
# 578                                         the City of
# 579                                              London
# 683                                               Sheba
# 900                                       other regions
# 1108                                      United States
# 1231                                           The city
# 1239                                         this place
# 1263                             a little market - town
# 1372                                           Damascus
# 1389                                           the city
# 1412                                             Halloa
# 1555                                             a city
# 1558                                        a real city
# 1609                                           Ebenezer
# 2186                                      Great Britain
# 2188                                           the town
# 3535  an obscure part of the town , where Scrooge ha...
# 4021                                            a place
# 4225                                     A worthy place
# 4744                                  the good old city
# 4745                            any other good old city
# 4746                                               town
# 4747                                            borough

# %% [markdown]
# We can see that cities (London, Damascus), or specific locations (Camdem Town, Bedlam (a 19th century asylum) appear under the category "PROP". It is true that "NOM" also includes geographic locations (such as United States or Great Britain), but there is also a lot of noise in there (The City, the town...). So let's just focus on extracting **PROP** (that means, proper nouns).

# %%
gpe_name = df[df["prop"] == "PROP"]

# %%
gpe_name
# Out:
#       COREF  start_token  end_token  prop  cat         text
# 336       1         2424       2424  PROP  GPE       Bedlam
# 537       3         3903       3904  PROP  GPE  Camden Town
# 579       4         4188       4188  PROP  GPE       London
# 683       5         5132       5132  PROP  GPE        Sheba
# 1372      9        11229      11229  PROP  GPE     Damascus
# 1412     10        11431      11431  PROP  GPE       Halloa
# 1609     26        12735      12735  PROP  GPE     Ebenezer

# %% [markdown]
# And now, to make sure that we are not speaking hundreds of times about the same location (i.e. London, that city, the town...), let's filter out things by "COREF". Now we will have just the number of locations appearing in the book!

# %%
unique_gpe_name = gpe_name.drop_duplicates(subset=['COREF'])

# %%
unique_gpe_name
# Out:
#       COREF  start_token  end_token  prop  cat         text
# 336       1         2424       2424  PROP  GPE       Bedlam
# 537       3         3903       3904  PROP  GPE  Camden Town
# 579       4         4188       4188  PROP  GPE       London
# 683       5         5132       5132  PROP  GPE        Sheba
# 1372      9        11229      11229  PROP  GPE     Damascus
# 1412     10        11431      11431  PROP  GPE       Halloa
# 1609     26        12735      12735  PROP  GPE     Ebenezer

# %%
mkdir output_files
# Out:
# Ya existe el subdirectorio o el archivo output_files.

# %%
unique_gpe_name.to_csv(r"output_files\a_christmas_carol_gpe.csv")

# %%
number_of_unique_gpe = len(unique_gpe_name)

# %%
number_of_unique_gpe
# Out:
# 7

# %% [markdown]
# So, we can see that if we compare number of characters with number of locations, the number of characters is much higher!
