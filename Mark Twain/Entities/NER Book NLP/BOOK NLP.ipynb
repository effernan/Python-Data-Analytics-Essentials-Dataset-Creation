# %% [markdown]
# Let's use BookNLP (https://github.com/booknlp/booknlp) to extract NER (Person, and Location), and POS (Part of Speech Tagging)

# %%
from booknlp.booknlp import BookNLP

# %%
model_params={
    "pipeline":"entity,quote,supersense,event,coref", 
    "model":"big"
}

# %%
booknlp = BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# --- startup: 8.991 seconds ---

# %%
pwd
# Out:
# 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities'

# %% [markdown]
#  # 1) A Connecticut Yankee

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\A Connecticut Yankee_NER.txt'
# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 
# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "a_connecticut_yankee"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 30.508 seconds ---
# --- entities: 546.719 seconds ---
# --- quotes: 0.213 seconds ---
# --- attribution: 515.135 seconds ---
# --- name coref: 1.023 seconds ---
# --- coref: 720.265 seconds ---
# --- TOTAL (excl. startup): 1815.707 seconds ---, 141406 words

# %% [markdown]
# # 2) A Horse Tale

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\A Horse’s Tale_NER.txt'
# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 
# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "a_horse_tale"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 4.967 seconds ---
# --- entities: 88.801 seconds ---
# --- quotes: 0.039 seconds ---
# --- attribution: 115.987 seconds ---
# --- name coref: 0.145 seconds ---
# --- coref: 119.074 seconds ---
# --- TOTAL (excl. startup): 329.209 seconds ---, 21785 words

# %% [markdown]
# # 3) Personal Recollections of Joan of Arc

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\Personal Recollections of Joan of Arc_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "Personal_Recollections_of_Joan_of_Arc"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 19.541 seconds ---
# --- entities: 382.418 seconds ---
# --- quotes: 0.158 seconds ---
# --- attribution: 318.552 seconds ---
# --- name coref: 0.507 seconds ---
# --- coref: 413.347 seconds ---
# --- TOTAL (excl. startup): 1135.773 seconds ---, 94379 words

# %% [markdown]
# # 4) The Adventures of Tom Sawyer

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\The Adventures of Tom Sawyer_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "The_Adventures_of_Tom_Sawyer"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 18.990 seconds ---
# --- entities: 286.109 seconds ---
# --- quotes: 0.145 seconds ---
# --- attribution: 366.494 seconds ---
# --- name coref: 0.302 seconds ---
# --- coref: 271.417 seconds ---
# --- TOTAL (excl. startup): 944.071 seconds ---, 88907 words

# %% [markdown]
# # 5) The American Claimant

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\The American Claimant_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "The_American_Claimant_NER"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 16.733 seconds ---
# --- entities: 262.815 seconds ---
# --- quotes: 0.159 seconds ---
# Cannot resolve quotation
# Cannot resolve quotation
# Cannot resolve quotation
# --- attribution: 314.252 seconds ---
# --- name coref: 0.316 seconds ---
# --- coref: 259.282 seconds ---
# --- TOTAL (excl. startup): 854.169 seconds ---, 80862 words

# %% [markdown]
# # 6) The Gilded Age

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\The Gilded Age_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "The_Gilded_Age"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 39.395 seconds ---
# --- entities: 648.839 seconds ---
# --- quotes: 0.271 seconds ---
# --- attribution: 592.562 seconds ---
# --- name coref: 2.422 seconds ---
# --- coref: 783.641 seconds ---
# --- TOTAL (excl. startup): 2068.396 seconds ---, 190770 words

# %% [markdown]
# # 7) The Prince and the Pauper_NER

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\The Prince and the Pauper_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "The_Prince_and_the_Pauper"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 14.770 seconds ---
# --- entities: 257.928 seconds ---
# --- quotes: 0.121 seconds ---
# --- attribution: 254.172 seconds ---
# --- name coref: 0.336 seconds ---
# --- coref: 271.447 seconds ---
# --- TOTAL (excl. startup): 799.649 seconds ---, 83773 words

# %% [markdown]
# # 8) The Tragedy of Pudd’nhead Wilson

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\The Tragedy of Pudd’nhead Wilson_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "The_Tragedy_of_Pudd’nhead_Wilson"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 11.832 seconds ---
# --- entities: 216.892 seconds ---
# --- quotes: 0.089 seconds ---
# --- attribution: 181.303 seconds ---
# --- name coref: 0.335 seconds ---
# --- coref: 219.024 seconds ---
# --- TOTAL (excl. startup): 629.876 seconds ---, 65233 words

# %% [markdown]
# # 9) Tom Sawyer Abroad

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\Tom Sawyer Abroad_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "Tom_Sawyer_Abroad"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 7.349 seconds ---
# --- entities: 134.234 seconds ---
# --- quotes: 0.073 seconds ---
# --- attribution: 115.480 seconds ---
# --- name coref: 0.103 seconds ---
# --- coref: 139.640 seconds ---
# --- TOTAL (excl. startup): 397.112 seconds ---, 42447 words

# %% [markdown]
# # 10) Tom Sawyer, Detective

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\Tom Sawyer, Detective_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "Tom_Sawyer_Detective"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 5.174 seconds ---
# --- entities: 89.246 seconds ---
# --- quotes: 0.057 seconds ---
# --- attribution: 80.300 seconds ---
# --- name coref: 0.076 seconds ---
# --- coref: 101.868 seconds ---
# --- TOTAL (excl. startup): 276.948 seconds ---, 28936 words

# %% [markdown]
# # 11) The Mysterious Stranger

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\The Mysterious Stranger_NER.txt'

# Output directory to store resulting files in
output_directory = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Mark Twain\\Entities\\files" 

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "The_Mysterious_Stranger"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 9.172 seconds ---
# --- entities: 151.056 seconds ---
# --- quotes: 0.083 seconds ---
# --- attribution: 106.446 seconds ---
# --- name coref: 0.069 seconds ---
# --- coref: 163.859 seconds ---
# --- TOTAL (excl. startup): 431.363 seconds ---, 49467 words
