# %% [markdown]
# Let's use BookNLP (https://github.com/booknlp/booknlp) to extract NER (Person, and Location), and POS (Part of Speech Tagging)

# %%
from booknlp.booknlp import BookNLP
# Out:
# using device cpu

# %%
model_params={
    "pipeline":"entity,quote,supersense,event,coref", 
    "model":"big"
}

# %%
booknlp = BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# --- startup: 10.123 seconds ---

# %%
pwd
# Out:
# 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER'

# %% [markdown]
#  # 1) A Son at the Front

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\A Son at the Front_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "a_son_at_the_front"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 29.167 seconds ---
# --- entities: 503.452 seconds ---
# --- quotes: 0.284 seconds ---
# --- attribution: 637.587 seconds ---
# --- name coref: 0.767 seconds ---
# --- coref: 625.084 seconds ---
# --- TOTAL (excl. startup): 1798.454 seconds ---, 120262 words

# %% [markdown]
# # 2) Summer

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\Summer_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "summer"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 15.330 seconds ---
# --- entities: 279.729 seconds ---
# --- quotes: 0.119 seconds ---
# --- attribution: 226.542 seconds ---
# --- name coref: 0.269 seconds ---
# --- coref: 344.351 seconds ---
# --- TOTAL (excl. startup): 866.907 seconds ---, 67701 words

# %% [markdown]
# # 3) The Age of Innocence

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Age of Innocence_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_age_of_innocence"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 26.535 seconds ---
# --- entities: 413.708 seconds ---
# --- quotes: 0.203 seconds ---
# --- attribution: 437.202 seconds ---
# --- name coref: 1.273 seconds ---
# --- coref: 448.547 seconds ---
# --- TOTAL (excl. startup): 1328.708 seconds ---, 123229 words

# %% [markdown]
# # 4) The Children

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Children_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_children"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 22.248 seconds ---
# --- entities: 374.984 seconds ---
# --- quotes: 0.189 seconds ---
# --- attribution: 542.269 seconds ---
# --- name coref: 0.469 seconds ---
# --- coref: 427.889 seconds ---
# --- TOTAL (excl. startup): 1368.923 seconds ---, 118435 words

# %% [markdown]
# # 5) The Custom of the Country

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Custom of the Country_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_custom_of_the_country"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 31.999 seconds ---
# --- entities: 548.378 seconds ---
# --- quotes: 0.310 seconds ---
# Cannot resolve quotation
# --- attribution: 646.456 seconds ---
# --- name coref: 1.057 seconds ---
# --- coref: 616.805 seconds ---
# --- TOTAL (excl. startup): 1846.282 seconds ---, 168180 words

# %% [markdown]
# # 6) The Fruit of the Tree

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Fruit of the Tree_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_fruit_of_the_tree"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 31.826 seconds ---
# --- entities: 562.002 seconds ---
# --- quotes: 0.292 seconds ---
# --- attribution: 736.295 seconds ---
# --- name coref: 0.538 seconds ---
# --- coref: 626.398 seconds ---
# --- TOTAL (excl. startup): 1958.741 seconds ---, 173230 words

# %% [markdown]
# # 7) The Glimpses of the Moon

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Glimpses of the Moon_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_glimpses_of_the_moon"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 17.813 seconds ---
# --- entities: 325.725 seconds ---
# --- quotes: 0.167 seconds ---
# --- attribution: 368.840 seconds ---
# --- name coref: 0.585 seconds ---
# --- coref: 355.064 seconds ---
# --- TOTAL (excl. startup): 1068.848 seconds ---, 100441 words

# %% [markdown]
# # 8) The House of Mirth

# %%
# Input file to process
input_file = 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The House of Mirth_NER.txt'

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_house_of_mirth"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 28.220 seconds ---
# --- entities: 485.625 seconds ---
# --- quotes: 0.266 seconds ---
# --- attribution: 392.504 seconds ---
# --- name coref: 0.864 seconds ---
# --- coref: 593.026 seconds ---
# --- TOTAL (excl. startup): 1502.810 seconds ---, 153642 words

# %% [markdown]
# # 9) The Mother's Recompense

# %%
# Input file to process
input_file = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Mother's Recompense_NER.txt"

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_mother_recompense"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 18.050 seconds ---
# --- entities: 359.013 seconds ---
# --- quotes: 0.232 seconds ---
# --- attribution: 497.214 seconds ---
# --- name coref: 0.696 seconds ---
# --- coref: 454.070 seconds ---
# --- TOTAL (excl. startup): 1330.463 seconds ---, 93071 words

# %% [markdown]
# # 10) The Reef_NER

# %%
# Input file to process
input_file = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Reef_NER.txt"

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_reef"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 24.478 seconds ---
# --- entities: 442.241 seconds ---
# --- quotes: 0.200 seconds ---
# --- attribution: 571.344 seconds ---
# --- name coref: 0.345 seconds ---
# --- coref: 575.624 seconds ---
# --- TOTAL (excl. startup): 1615.787 seconds ---, 116568 words

# %% [markdown]
# # 11) The Valley of Decision

# %%
# Input file to process
input_file = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\The Valley of Decision_NER.txt"

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "the_valley_of_decision"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 36.431 seconds ---
# --- entities: 701.016 seconds ---
# --- quotes: 0.300 seconds ---
# --- attribution: 508.956 seconds ---
# --- name coref: 2.089 seconds ---
# --- coref: 858.872 seconds ---
# --- TOTAL (excl. startup): 2109.489 seconds ---, 178293 words

# %% [markdown]
# # 12) Twilight Sleep

# %%
# Input file to process
input_file = "C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\Twilight Sleep_NER.txt"

# Output directory to store resulting files in
output_directory= 'C:\\Users\\usuario\\ELENA\\it-training uzh\\it-training uzh\\Python Data Analytics Essentials\\Edith Warton\\entities\\NER\\files'

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id = "twilight_sleep"

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 22.464 seconds ---
# --- entities: 399.096 seconds ---
# --- quotes: 0.164 seconds ---
# --- attribution: 529.215 seconds ---
# --- name coref: 0.718 seconds ---
# --- coref: 510.785 seconds ---
# --- TOTAL (excl. startup): 1464.341 seconds ---, 101892 words
